# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
cat = Image.open('../../images/cat.jpg')
plt.imshow(cat)
plt.show()

# %%
def convolution(I: np.ndarray, kernel_size: int=3) -> np.ndarray:
    
    pass
